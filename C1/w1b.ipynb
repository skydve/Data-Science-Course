# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as sc

# %%
x = np.arange(1, 15, 0.1)

def f(x):
    return math.sin(x / 5) * math.exp(x / 10) + 5 * math.exp(-x / 2)

print(f(1), f(15))

y0 = [math.sin(i / 5) * math.exp(i / 10) + 5 * math.exp(-i / 2) for i in x]

#plt.plot(x, y)
#plt.show()
# Out:
# 3.252216865271419 0.6352214195786656

# %%
a = np.array([[1, 1],
              [1, 15]])

b = np.array([f(1), f(15)])

w = sc.solve(a, b)

y1 = [(w[0] + w[1]*i) for i in x]

# %%
a2 = np.array([[1, 1, 1],
               [1, 8, 64],
               [1, 15, 225]])

b2 = np.array([f(1), f(8), f(15)])

w2 = sc.solve(a2, b2)

y2 = [(w2[0] + w2[1] * i + w2[2] * i**2) for i in x]

plt.plot(x, y1)
plt.plot(x, y0)
plt.plot(x, y2)
plt.show()
# Out:
# [ 3.32512949 -0.06531159 -0.00760104]

# %%
a3 = np.array([[1, 1, 1, 1],
               [1, 4, 16, 64],
               [1, 10, 100, 1000],
               [1, 15, 225, 3375]])

b3 = np.array([f(1), f(4), f(10), f(15)])

w3 = sc.solve(a3, b3)

print(w3)

y3 = [(w3[0] + w3[1]*i + w3[2]*i**2 + w3[3]*i**3) for i in x]

plt.plot(x, y1)
plt.plot(x, y0)
plt.plot(x, y3)
plt.show()
# Out:
# [ 4.36264154 -1.29552587  0.19333685 -0.00823565]
